# %% [markdown]
# #typecasting / type conversion
# #two types:
# #1.implicit
# #2.explicit

# %%
a=10 #int
b=2 #int
c=a/b
c= int(c)
print(a,type(a))
print(b,type(b))
print(c,int(c),type(c))
# Out:
# 10 <class 'int'>
# 2 <class 'int'>
# 5 5 <class 'int'>

# %%
x="123.29ab"
print(x,type(x))
y=str(x)
print(y,type(y))
# Out:
# 123.29ab <class 'str'>
# 123.29ab <class 'str'>

# %%
#taking inout from user
age=int(input("enter the age"))
print("the age is ",age,type(age))
# Out:
# the age is  12 <class 'int'>

# %%
num1=float(input("enter the number"))
num2=float(input("enter the secinf number"))
sum=num1+num2
diffrence=num1-num2
product=num1*num2
divide=num1/num2
print("sum",sum)
print("diffrence",diffrence)
print("product",product)
print("division",divide)
# Out:
# sum 36.0
# diffrence -12.0
# product 288.0
# division 0.5
