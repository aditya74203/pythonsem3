# %%
age=int(input("enter the age"))
if age==18:
    print("you are allowed")

# %%
age=int(input("enter the age"))
if age>18:
    print("you are eligible")
else:
    print("you are minor")
# Out:
# you are minor

# %%
age=int(input("enter the age"))
if age<13:
    print("you are child")
elif age<18:
    print("you are minor")

# %%
#nested if else
num=int(input("enter the number"))
if num>0:
    print("THE NUMBER IS POSITIVE")
    if num%2==0:
        print("the number is even")
    else:
        print("the number ius odd")
else:
    print("the number is negative or zero")
# Out:
# THE NUMBER IS POSITIVE
# the number is even

# %%
year=int(input("enter the number"))
if year%4==0:
    if year%100==0:
        if year%400==0:
            print("leap year")
        else:
            print("not leap year")
    else:
        print(" not leap year")
else:
    print("not leap year")
# Out:
# not leap year

# %%
a=int(input("enter the first number"))
b=int(input("enter the second number"))
sum==a+b
mul=a*b
div=a/b
sub=a-b

# %%
age=int(input("enter the age"))
student=str(input("if student type yes"))
if age==5:
    price="free"
elif age<=12:
    price="$10"
elif age<=17:
    if student=='yes':
        price="$12"
    else:
        price="$15"
elif age<=20:
    if student=='yes':
        price="$15"
    else:
        price="$20"
print(price)
# Out:
# $12
