# %%
age=int(input("enter the age"))
if age==18:
    print("you are allowed")

# %%
age=int(input("enter the age"))
if age>18:
    print("you are eligible")
else:
    print("you are minor")
# Out:
# you are minor

# %%
age=int(input("enter the age"))
if age<13:
    print("you are child")
elif age<18:
    print("you are minor")
