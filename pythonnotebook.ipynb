# %%
a=10

# %%
name="aadi"
Name="sid"
NAME="aryan"
print(name)
# Out:
# aadi

# %%
print(Name)
print(NAME)
# Out:
# sid
# aryan

# %%
age=14
if age>18:
    print(age)
print(age)
# Out:
# 14

# %%
total=1+2+3+4+5+6+7
print(total)
# Out:
# 28

# %%
college_name="abes engineering \
 college"
print(college_name)
# Out:
# abes engineering  college

# %%
x=5;y=6;z=9
print(x,y,z)
# Out:
# 5 6 9

# %%
#litterals and their diffrent type
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
variable=10
print(type(variable))
variable="aadi"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
a=10+6j
print(type(a))
type(a)
# Out:
# <class 'complex'>
# complex

# %%
x=True
print(x)
type(x)
# Out:
# True
# bool

# %%
y=None
print(y)
type(y)
# Out:
# None
# NoneType

# %%
#collections
# 1.list
A=[1,2,None,2.4,"hello",6+6j,True,1,2.4]
print(A)
print(type(A))
# Out:
# [1, 2, None, 2.4, 'hello', (6+6j), True, 1, 2.4]
# <class 'list'>

# %%
#2.tuple
B = (1,2,None,2.4,"hello",6+6j,True,1,2.4)
print(B)
print(type(B))
# Out:
# (1, 2, None, 2.4, 'hello', (6+6j), True, 1, 2.4)
# <class 'tuple'>

# %%
#3.set
C={1,2,None,2.4,"hello",6+6j,True,1,2.4}
print(C)
print(type(C))
# Out:
# {None, 1, 2, 2.4, (6+6j), 'hello'}
# <class 'set'>

# %%
#4.dictionary
D={1:"a",3:"c",2:"b"}
print(D)
print(type(D))
# Out:
# {1: 'a', 3: 'c', 2: 'b'}
# <class 'dict'>
