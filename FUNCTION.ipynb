# %%
def sum(a,b):
    return(a+b)
a=int(input("enter the first number "))
b=int(input("enter the second number"))
sum(a,b)
# Out:
# 9

# %%
def sub(a,b):
    return(a-b)
def mul(a,b):
    return(a*b)
def div(a,b):
    return(a/b)
def fun(n):
    if(n==1):
        return(sum(a,b))
    elif(n==2):
        return(sub(a,b))
    elif(n==3):
        return(mul(a,b))
    elif(n==4):
        return(div(a,b))
a=int(input("enter the first number"))
b=int(input("enter the second number"))
n=int(input("enter the n"))
print(fun(n))
# Out:
# 8

# %%
def greet(name):
    print(F"hello {name} welcome to the paradise")
greet("krish")
# Out:
# hello krish welcome to the paradise

# %% [markdown]
# # parameters
# #! default arguments
# #2 arbitrary argument
# #3 positional argument
# #4 keyword argument

# %%
#default argument
def areacircle(r,pie=3.14):
    return(r*pie*r)
areacircle(7)
# Out:
# 153.86

# %%
# keyword arguments
# def add(a,b,c):
#     return(a+b+c)
# add(b=10,c=30,a=33)
def sub(a,b,c):
    return(a-b-c)
sub(a=10,b=10,c=15)
# Out:
# -15

# %% [markdown]
# # keyword arbitory(**kwargs)

# %%
def addition(*args):
    print(type(args))
    sum=0
    for i in args:
        sum=sum+i
    return sum 
result=addition(4,3,5,4,3,5)
print(result)
# Out:
# <class 'tuple'>
# 24

# %%
def addition(**kwargs):
    print(type(kwargs))
    sum=0
    for i in kwargs:
        sum+=kwargs[i]
    return sum 
result=addition(a=4,b=3,c=5,d=4,f=3,h=5)
print(result)
# Out:
# <class 'dict'>
# 24

# %%
def addition(**kwargs):
    print(type(kwargs))
    sum=0
    for i in kwargs.keys():
        print(i)
    for i in kwargs.values():
        print(i)
    for i in kwargs.items():
        print(i)        
    return sum 
result=addition(a=4,b=3,c=5,d=4,f=3,h=5)
print(result)
# Out:
# <class 'dict'>
# a
# b
# c
# d
# f
# h
# 4
# 3
# 5
# 4
# 3
# 5
# ('a', 4)
# ('b', 3)
# ('c', 5)
# ('d', 4)
# ('f', 3)
# ('h', 5)
# 0

# %% [markdown]
# write a program to genrate perfect numbers from 1 to 1000

# %%
def is_perfect(num):
    sum_divisors = 0

    for i in range(1, num):
        if num % i == 0:
            sum_divisors += i

    return sum_divisors == num


for num in range(1, 1001):
    if is_perfect(num):
        print(num)
# Out:
# 6
# 28
# 496

# %%
def division(a,b):
    if b!=0:
        return(a/b,a//b)
    else:
        print("error division by 0")
print(type(division(10,3)))
# Out:
# <class 'tuple'>

# %% [markdown]
# write a prongram to convert the temperature in either celsius oe fer as in put user provide temperature and its unit

# %%
temp=float(input("enter the temperature"))
unit=str(input("enter c or f").upper())
if unit=="C":
    fah=(temp*9/5)+32
    print("the temp in fah is",fah,"f")
elif unit=="F":
    cel=(temp-32)*5/9
    print("the temp in cel is",cel,"C")
else:
    print("invlaid unit please enter c or f")
# Out:
# the temp in fah is 132.8 f

# %% [markdown]
# write a program for password checker

# %%
def is_strong_password(password):
    if len(password)<0:
        return False
    if not any(char.isdigit() for char in password):
        return False
    if not any(char.isupper() for char in password):
        return False
    if not any(char.islower() for char in password):
        return False
    if not any(char in '!@#$%^&*' for char in password):
        return False
    return True
password=input("enter the password")
if(is_strong_password(password)):
    print("password is strong")
# print(is_strong_password("Aadi@0000"))
# Out:
# password is strong

# %%
def calculate_total_cost(cart):
        total_cost=0
        for item in cart:
                total_cost += item['price']* item['quantity']
        return total_cost
cart=[
        {'name':'apple','price':0.5,'quantity':4},
        {'name':'banana','price':0.3,'quantity':6},
        {'name':'orange','price':0.7,'quantity':3}
]
total_cost=calculate_total_cost(cart)
print("Total cost of the cart is:", total_cost)
# Out:
# Total cost of the cart is: 5.8999999999999995

# %% [markdown]
# check if a string is palindrome

# %%
def is_palindrome(string):
    string=string.lower()
    return string==string[::-1]
print(is_palindrome("Aadi"))
print(is_palindrome("hello"))
print(is_palindrome("naman"))
# Out:
# False
# False
# True

# %%
def is_palindrome(string):
    string=string.lower()
    return string==string[-3:-1:-1]
print(is_palindrome("Aadi"))
print(is_palindrome("hello"))
print(is_palindrome("naman"))
# Out:
# False
# False
# False
