# %%
a=10
b=10
print(a is b)
print(a==b)
print(id(a),id(b))
# Out:
# True
# True
# 140722841818312 140722841818312

# %%
import copy
x=10
y=copy.copy(x)
print(id(x),id(y))
print(x is y)
# Out:
# 140722841818312 140722841818312
# True
